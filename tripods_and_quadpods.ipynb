# %%
# %load_ext autoreload
# %autoreload 2

# %%
import calcLattice
from calcLattice import make_lattice, reset, set_up_tripods, set_up_quadpods
import draw
from draw import make_figure
# %matplotlib inline
import matplotlib as mpl
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.collections import PatchCollection
from calcLattice import tiles, positions_list, orientations_list, types_list
from calcLattice import angles, lengths, IDs
from calcLattice import gluing_mapping

# %% [markdown]
# ### The key to using global variables for lists and dictionaries is to remember that they are Objects, so rather than reassigning them, we simply need to clear them and update.

# %%
global tiles, positions_list, orientations_list, types_list, gluing_mapping
global angles, lengths, IDs

# %%
set_up_quadpods()
gluing_mapping.clear()
# gluing_mapping.update({1: 1, 2: 2, 3: 3, 4: 4})
# gluing_mapping.update({1: 1, 2: 1, 3: 1, 4: 0})
gluing_mapping.update({1: 0, 2: 0, 3: 4, 4: 1})
# gluing_mapping.update({1: 0, 2: 1, 3: 2, 4: 1})

reset()
make_lattice()
fig = make_figure(shape=4)

# %%
set_up_tripods()
gluing_mapping.clear()
gluing_mapping.update({1:4, 2:3, 3:2, 4:1, 5:0, 6:0}) #snow flake

reset()
make_lattice()

fig = make_figure(shape=3)
